# %%
import pandas as pd
import numpy as np
import nltk
import sqlite3
from tkinter import *
import matplotlib.pyplot as plt
import os

# %%
csv_file_path = os.path.join("food_reviews_500x3.csv")
df = pd.read_csv(csv_file_path)

# %%
df.head()
# Out:
#     food_item     review sentiment
# 0       Pizza   Too oily  Negative
# 1       Pasta  Bad taste  Negative
# 2      Burger   Loved it  Positive
# 3  Fried Rice   Loved it  Positive
# 4       Pasta   Not good  Negative

# %%
df.shape
# Out:
# (500, 3)

# %%
df.isnull().sum()
# Out:
# food_item    0
# review       0
# sentiment    0
# dtype: int64

# %%
user = input("Enter user type (owner/customer): ")
print("User type is:", user)
# Out:
# Enter user type (owner/customer): owner
# User type is: owner

# %%
food_item = input("Enter food item: ")
review = input("Enter your review about the food: ")
# Out:
# Enter food item: briyani
# Enter your review about the food: good

# %%
df.columns
# Out:
# Index(['food_item', 'review', 'sentiment'], dtype='object')

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative    273
# Positive    227
# Name: count, dtype: int64

# %%
df['sentiment'].value_counts().plot(kind='bar')

plt.title("Sentiment Analysis of Food Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")

plt.show()

# %%
owner_code = "1234"
user_code = input("Enter verification code: ")
# Out:
# Enter verification code: 123

# %%
if user_code == owner_code:
    print("Ownership verified")
else:
    print("Access denied")
# Out:
# Access denied

# %%
print("1. Popup")
print("2. Root folder")
print("3. View data")

choice = input("Enter your choice: ")
# Out:
# 1. Popup
# 2. Root folder
# 3. View data
# Enter your choice: 2

# %%
if choice == "1":
    print("Popup message displayed")

elif choice == "2":
    print("Opening root folder")

elif choice == "3":
    print(df)

else:
    print("Invalid option")
# Out:
# Opening root folder

# %%
print(df)
# Out:
#       food_item          review sentiment
# 0         Pizza        Too oily  Negative
# 1         Pasta       Bad taste  Negative
# 2        Burger        Loved it  Positive
# 3    Fried Rice        Loved it  Positive
# 4         Pasta        Not good  Negative
# ..          ...             ...       ...
# 495    Sandwich        Not good  Negative
# 496      Burger       Not fresh  Negative
# 497       Pizza      Very tasty  Positive
# 498    Sandwich  Amazing flavor  Positive
# 499    Sandwich        Loved it  Positive
#
# [500 rows x 3 columns]

# %%
df.groupby('food_item')['sentiment'].value_counts()
# Out:
# food_item   sentiment
# Biryani     Negative     22
#             Positive     18
# Burger      Negative     38
#             Positive     27
# Cake        Negative     29
#             Positive     25
# Dosa        Negative     22
#             Positive     14
# Fried Rice  Negative     28
#             Positive     28
# Noodles     Negative     20
#             Positive     15
# Pasta       Negative     30
#             Positive     16
# Pizza       Negative     31
#             Positive     28
# Sandwich    Negative     30
#             Positive     30
# Soup        Positive     26
#             Negative     23
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
print("Cleaned Data:")
print(df)
# Out:
# Cleaned Data:
#       food_item               review sentiment
# 0         Pizza             Too oily  Negative
# 1         Pasta            Bad taste  Negative
# 2        Burger             Loved it  Positive
# 3    Fried Rice             Loved it  Positive
# 4         Pasta             Not good  Negative
# ..          ...                  ...       ...
# 292     Biryani             Not good  Negative
# 317    Sandwich  Fresh and delicious  Positive
# 346     Biryani            Not fresh  Negative
# 414       Pasta       Amazing flavor  Positive
# 459     Noodles  Fresh and delicious  Positive
#
# [100 rows x 3 columns]
